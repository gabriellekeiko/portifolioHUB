# %% [markdown]
# # Atividade 1 — Exercícios com os comandos básicos de pandas para EDA
#
#
# Responda as perguntas abaixo no notebook (cada resposta deve ter ao menos uma célula de código que produza o output e, logo abaixo, uma célula de texto com a sua interpretação).

# %% [markdown]
# ## 1) Carregue o dataset e mostre as primeiras 10 linhas.

# %%
import pandas as pd

df = pd.read_csv('emendas.csv')
df.head(10)
# Out:
# /tmp/ipykernel_12977/421898870.py:3: DtypeWarning: Columns (0,3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('emendas.csv')
#   Código da Emenda  Ano da Emenda  \
# 0   Sem informação           2014
# 1   Sem informação           2014
# 2   Sem informação           2014
# 3   Sem informação           2014
# 4   Sem informação           2014
# 5   Sem informação           2014
# 6   Sem informação           2014
# 7   Sem informação           2014
# 8   Sem informação           2014
# 9   Sem informação           2014
#
#                                       Tipo de Emenda  \
# 0  Emenda Individual - Transferências com Finalid...
# 1  Emenda Individual - Transferências com Finalid...
# 2  Emenda Individual - Transferências com Finalid...
# 3  Emenda Individual - Transferências com Finalid...
# 4  Emenda Individual - Transferências com Finalid...
# 5  Emenda Individual - Transferências com Finalid...
# ...

# %% [markdown]
# Explique em uma frase o que você observa nas primeiras 10 linhas.

# %% [markdown]
# As primeiras 10 linhas mostram registros de emendas individuais do ano de 2014, detalhando a localização de aplicação do recurso (município/UF) e os valores destinados a diferentes ações orçamentárias.

# %% [markdown]
# ## 2) Quantas linhas e colunas o dataset possui?

# %%
df.shape
# Out:
# (71832, 28)

# %% [markdown]
# Explique o que esses números significam.

# %% [markdown]
# O dataset possui 71832 linhas (registros) e 28 colunas (variáveis/atributos), indicando o volume total de dados disponíveis para esta análise.

# %% [markdown]
# ## 3) Liste os nomes das colunas e descreva brevemente o que você entende que cada coluna representa.

# %%
df.columns
# Out:
# Index(['Código da Emenda', 'Ano da Emenda', 'Tipo de Emenda',
#        'Código do Autor da Emenda', 'Nome do Autor da Emenda',
#        'Número da emenda', 'Localidade de aplicação do recurso',
#        'Código Município IBGE', 'Município', 'Código UF IBGE', 'UF', 'Região',
#        'Código Função', 'Nome Função', 'Código Subfunção', 'Nome Subfunção',
#        'Código Programa', 'Nome Programa', 'Código Ação', 'Nome Ação',
#        'Código Plano Orçamentário', 'Nome Plano Orçamentário',
#        'Valor Empenhado', 'Valor Liquidado', 'Valor Pago',
#        'Valor Restos A Pagar Inscritos', 'Valor Restos A Pagar Cancelados',
#        'Valor Restos A Pagar Pagos'],
#       dtype='object')

# %% [markdown]
# Escreva sua breve descrição das colunas, como se estivesse criando um dicionário de variáveis para que leitor entenda.

# %% [markdown]
# Código da Emenda: Identificador numérico único da emenda.
#
# Ano da Emenda: Ano do exercício financeiro em que a emenda foi criada.
#
# Tipo de Emenda: Classificação da origem (ex: Individual, de Bancada, de Relator).
#
# Código do Autor da Emenda: ID numérico do parlamentar que indicou o recurso.
#
# Nome do Autor da Emenda: Nome do Deputado ou Senador autor da emenda.
#
# Número da emenda: Código sequencial da emenda no orçamento.
#
# Localidade de aplicação do recurso: Descrição do destino final da verba.
#
# Código Município IBGE / Município: Identificadores da cidade beneficiada.
#
# Código UF IBGE / UF / Região: Identificadores do estado e região do país.
#
# Código Função / Nome Função: Área de governo (ex: Saúde, Educação, Segurança).
#
# Código Subfunção / Nome Subfunção: Segmento específico da área (ex: Atenção Básica).
#
# Código Programa / Nome Programa: Nome do programa orçamentário do Governo.
#
# Código Ação / Nome Ação: Atividade específica que receberá o investimento.
#
# Código / Nome Plano Orçamentário: Detalhamento técnico da execução orçamentária.
#
# Valor Empenhado: Valor que o governo se comprometeu a pagar (reservado).
#
# Valor Liquidado: Valor onde o serviço/bem já foi comprovadamente entregue.
#
# Valor Pago: Valor que já saiu dos cofres públicos para o beneficiário.
#
# Valor Restos A Pagar Inscritos: Dívidas de anos anteriores reconhecidas.
#
# Valor Restos A Pagar Cancelados: Valores de anos anteriores que não serão mais pagos.
#
# Valor Restos A Pagar Pagos: Valores de anos anteriores que foram quitados agora..

# %% [markdown]
# ## 4) Existem valores nulos? quantos?

# %%
df.isnull().sum()
# Out:
# Código da Emenda                      0
# Ano da Emenda                         0
# Tipo de Emenda                        0
# Código do Autor da Emenda             0
# Nome do Autor da Emenda               0
# Número da emenda                      0
# Localidade de aplicação do recurso    0
# Código Município IBGE                 0
# Município                             0
# Código UF IBGE                        0
# UF                                    0
# Região                                0
# Código Função                         0
# Nome Função                           0
# Código Subfunção                      0
# Nome Subfunção                        0
# Código Programa                       0
# Nome Programa                         0
# Código Ação                           0
# Nome Ação                             0
# Código Plano Orçamentário             1
# Nome Plano Orçamentário               1
# Valor Empenhado                       1
# ...

# %% [markdown]
# ## 5) Mostre os tipos das variáveis (se int, string, boolean, float...) e analise se alguma variável parece ter o tipo errado. Faça isso da maneira mais objetiva e otimizada possível.

# %%
df.dtypes
# Out:
# Código da Emenda                      object
# Ano da Emenda                          int64
# Tipo de Emenda                        object
# Código do Autor da Emenda             object
# Nome do Autor da Emenda               object
# Número da emenda                      object
# Localidade de aplicação do recurso    object
# Código Município IBGE                 object
# Município                             object
# Código UF IBGE                         int64
# UF                                    object
# Região                                object
# Código Função                         object
# Nome Função                           object
# Código Subfunção                      object
# Nome Subfunção                        object
# Código Programa                       object
# Nome Programa                         object
# Código Ação                           object
# Nome Ação                             object
# Código Plano Orçamentário             object
# ...

# %% [markdown]
# Se alguma coluna estiver com o tipo errado, escreva abaixo qual é e por que isso pode atrapalhar análises.
#
# **Dica:** Se alguma variável tiver no tipo o nome "object", isso se refere a texto.

# %% [markdown]
# As colunas financeiras — Valor Empenhado, Valor Liquidado, Valor Pago e as colunas de Restos a Pagar — estão todas classificadas como object (texto).
#
# Impossibilidade de cálculos: Como o Python entende que esses valores são "palavras", não podemos somar o total gasto, calcular a média de valores por região ou encontrar a emenda mais cara. Se tentarmos somar, o Python dará erro ou apenas juntará os textos.

# %% [markdown]
# ## 6) Usando a coluna `Ano da Emenda` como base, descubra até que ano o dataset está atualizado (mostre as 8 primeiras linhas do df ordenado desc).

# %%
df_ordenado = df.sort_values(by='Ano da Emenda', ascending=False)
df_ordenado.head(8)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 71783     202323680003           2023
# 71830     202331340003           2023
# 71812     202329790007           2023
# 71829     202331340002           2023
# 71828     202331340001           2023
# 71811     202329790006           2023
# 71810     202329790005           2023
# 71799     202323680020           2023
#
#                                           Tipo de Emenda  \
# 71783  Emenda Individual - Transferências com Finalid...
# 71830  Emenda Individual - Transferências com Finalid...
# 71812  Emenda Individual - Transferências com Finalid...
# 71829  Emenda Individual - Transferências com Finalid...
# 71828  Emenda Individual - Transferências com Finalid...
# 71811  Emenda Individual - Transferências com Finalid...
# 71810  Emenda Individual - Transferências com Finalid...
# 71799       Emenda Individual - Transferências Especiais
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# ...

# %% [markdown]
# Explique: qual é o ano mais recente presente no dataset?

# %% [markdown]
# 2023

# %% [markdown]
# ## 7) execute um  `describe()` e explique uma conclusão simples que você consegue tirar a partir das estatísticas (se algumas colunas deveriam aparecer no describe mas não aparecem, indique o motivo que você acredita que esteja causando esse problema).

# %%
df.describe()
# Out:
#        Ano da Emenda  Código UF IBGE
# count   71832.000000    7.183200e+04
# mean     2017.995796    2.981596e+06
# std         2.664694    1.227537e+06
# min      2014.000000   -1.400000e+01
# 25%      2016.000000    2.300000e+06
# 50%      2018.000000    3.100000e+06
# 75%      2020.000000    3.500000e+06
# max      2023.000000    5.300000e+06

# %% [markdown]
# Conclusão Simples sobre os dados visíveis:
# Período dos Dados: O dataset cobre emendas de 2014 (valor mínimo) até 2023 (valor máximo).
#
# Média Temporal: A média dos anos é aproximadamente 2018, indicando que há um volume equilibrado de dados ao longo da última década.
#
# Volume de Registros: O campo count mostra que temos 71.832 linhas com dados válidos nessas colunas.
#
#
# Colunas que deveriam aparecer, mas não aparecem:
# As colunas de Valor Empenhado, Valor Liquidado e Valor Pago são as mais importantes do dataset, mas ficaram de fora do resumo estatístico.
#
#
# Motivo do problema:
# Isso acontece porque essas colunas estão configuradas como o tipo object (texto), conforme vimos no teste anterior (df.dtypes).

# %% [markdown]
# ## 8) Mostre as últimas 5 linhas do dataset e escreva se a última linha parece completa (sem muitos nulos) ou não.

# %%
df.tail(5)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 71827     202328360003           2023
# 71828     202331340001           2023
# 71829     202331340002           2023
# 71830     202331340003           2023
# 71831     202331340004           2023
#
#                                           Tipo de Emenda  \
# 71827       Emenda Individual - Transferências Especiais
# 71828  Emenda Individual - Transferências com Finalid...
# 71829  Emenda Individual - Transferências com Finalid...
# 71830  Emenda Individual - Transferências com Finalid...
# 71831  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 71827                      2836              FABIO TRAD                3
# 71828                      3134           FAUSTO PINATO                1
# 71829                      3134           FAUSTO PINATO                2
# 71830                      3134           FAUSTO PINATO                3
# ...

# %% [markdown]
# Interprete a completude da última linha.

# %% [markdown]
# Ao executar o comando df.tail(5), observa-se que as últimas linhas do dataset apresentam informações sobre emendas do ano de 2023. A última linha parece estar incompleta, pois possue campos que não possuem dados preenchidos, com excesso de valores nulos (NaN) que indicariam um erro no carregamento do arquivo

# %% [markdown]
# ## 9) existem valores duplicados no dataframe? Caso positivo, quantos?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Não existem valores duplicados no dataframe. Ao executar o comando df.duplicated().sum(), o retorno foi 0, o que confirma que cada linha do conjunto de dados representa um registro único. Isso garante que não haverá contagem dupla de valores financeiros ou distorções nas análises estatísticas por conta de repetições desnecessárias.
